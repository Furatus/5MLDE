# %%
import sqlalchemy
import pandas as pd
import psycopg
from sqlalchemy import create_engine

# %%
dbconn = create_engine("postgresql+psycopg://user:password@localhost/dbname")

pd.read_sql_table("winequality", con=dbconn)
